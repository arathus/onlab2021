# %%
from plotly.offline import iplot
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.pyplot import figure
import plotly.express as px
import pandas as pd
import numpy as np
from os import walk
from tqdm.auto import tqdm
from datetime import datetime
import seaborn as sn
from sklearn.cluster import KMeans

# %%
train_df = pd.read_csv("./aggregated_data/labeled_5s_candles.csv")
train_df.drop(["Unnamed: 0"], axis=1, inplace=True)
train_df.dropna(inplace=True)
train_df
# Out:
#                  timestamp     open     high      low    close    volume  \
# 12     2021-02-27 15:08:55  1483.68  1483.92  1483.56  1483.56   8.40117
# 13     2021-02-27 15:09:00  1483.27  1483.28  1483.11  1483.11   1.92292
# 14     2021-02-27 15:09:05  1482.49  1482.49  1482.16  1482.19   3.57305
# 15     2021-02-27 15:09:10  1482.36  1482.73  1482.22  1482.73   2.02586
# 16     2021-02-27 15:09:15  1482.60  1483.39  1482.51  1483.39   1.71675
# ...                    ...      ...      ...      ...      ...       ...
# 34318  2021-03-01 14:26:00  1530.01  1530.49  1530.00  1530.49  15.21124
# 34319  2021-03-01 14:26:05  1530.42  1530.42  1530.01  1530.08   3.90970
# 34320  2021-03-01 14:26:10  1530.00  1530.25  1530.00  1530.25  11.90400
# 34321  2021-03-01 14:26:15  1530.56  1531.35  1530.56  1531.35   2.72905
# 34322  2021-03-01 14:26:20  1531.75  1531.76  1531.43  1531.60   3.85500
#
#           score
# 12    -0.956559
# 13    -1.064994
# 14    -1.053513
# 15    -0.954966
# 16    -0.859152
# ...         ...
# 34318 -0.521830
# 34319 -0.378777
# 34320 -0.241758
# 34321 -0.114336
# 34322  0.088264
#
# [34311 rows x 7 columns]

# %%
kmeans = KMeans(algorithm='auto', init='k-means++', max_iter=1000,
    n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
    random_state=42, tol=0.001, verbose=0)

train_df["class"]  = kmeans.fit_predict(train_df[['score']])

heights = train_df["class"].value_counts()/len(train_df["class"])
print(heights)
train_df["percs"] = train_df["class"].map(heights.to_dict())
train_df
# Out:
# /home/arathus/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:788: FutureWarning:
#
# 'precompute_distances' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25). It has no effect
#
# /home/arathus/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning:
#
# 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
# 0    0.366734
# 4    0.280260
# 1    0.230276
# 2    0.070706
# 3    0.052024
# Name: class, dtype: float64
#                  timestamp     open     high      low    close    volume  \
# 12     2021-02-27 15:08:55  1483.68  1483.92  1483.56  1483.56   8.40117
# 13     2021-02-27 15:09:00  1483.27  1483.28  1483.11  1483.11   1.92292
# 14     2021-02-27 15:09:05  1482.49  1482.49  1482.16  1482.19   3.57305
# 15     2021-02-27 15:09:10  1482.36  1482.73  1482.22  1482.73   2.02586
# 16     2021-02-27 15:09:15  1482.60  1483.39  1482.51  1483.39   1.71675
# ...                    ...      ...      ...      ...      ...       ...
# 34318  2021-03-01 14:26:00  1530.01  1530.49  1530.00  1530.49  15.21124
# 34319  2021-03-01 14:26:05  1530.42  1530.42  1530.01  1530.08   3.90970
# 34320  2021-03-01 14:26:10  1530.00  1530.25  1530.00  1530.25  11.90400
# 34321  2021-03-01 14:26:15  1530.56  1531.35  1530.56  1531.35   2.72905
# 34322  2021-03-01 14:26:20  1531.75  1531.76  1531.43  1531.60   3.85500
#
#           score  class     percs
# 12    -0.956559      4  0.280260
# 13    -1.064994      4  0.280260
# 14    -1.053513      4  0.280260
# 15    -0.954966      4  0.280260
# 16    -0.859152      4  0.280260
# ...         ...    ...       ...
# 34318 -0.521830      4  0.280260
# 34319 -0.378777      4  0.280260
# 34320 -0.241758      0  0.366734
# 34321 -0.114336      0  0.366734
# 34322  0.088264      0  0.366734
#
# [34311 rows x 9 columns]

# %%
def relabel_df(train_df):
    relabel_dict = {
        1:3,
        4:1,
        2:0,
        3:4,
        0:2
    }
    train_df["class"] = train_df["class"].map(relabel_dict)
    
def relabel_prediction(array):
    relabel_dict = {
        1:3,
        4:1,
        2:0,
        3:4,
        0:2
    }
    return np.vectorize(relabel_dict.get)(array)

# %%
relabel_df(train_df)

heights = train_df["class"].value_counts()/len(train_df["class"])
print(heights)
ar = train_df["score"].values
y = train_df["percs"].values
label = train_df["class"].values

colors = ['yellow','green','blue', "red", "magenta"]

plt.figure(figsize=(18,8))
plt.scatter(ar, y + 0., c=label,cmap=matplotlib.colors.ListedColormap(colors))
plt.title('Distribution of classes')
plt.ylabel('Percentage of class in dataset')
plt.xlabel('Score values')
# Out:
# 2    0.366734
# 1    0.280260
# 3    0.230276
# 0    0.070706
# 4    0.052024
# Name: class, dtype: float64
# Text(0.5, 0, 'Score values')

# %%
dl_train1 = train_df.copy()

params = np.array(dl_train1.drop(["score", "timestamp", "class", "percs"], axis=1).values)
all_arr = list()
for i in tqdm(range(13, len(params))):
    all_arr.append((params[i-12:i]/params[i-13])-1)
    
x = np.array(all_arr)

_y = np.array(dl_train1[["class"]].values)

y = _y

x = x
y = y[13:]

print(np.shape(x))
print(np.shape(y))
# Out:
#   0%|          | 0/34298 [00:00<?, ?it/s]
# (34298, 12, 5)
# (34298, 1)

# %%
# random shuffle
import random
from sklearn.model_selection import train_test_split

random.seed(42)

concat = list(zip(x,y))
random.shuffle(concat)

x, y = zip(*concat)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 42)
X_train, X_test, y_train, y_test = np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

## one-hot encoding
a = y_train.reshape(-1)
b = np.zeros((a.size, a.max()+1))
b[np.arange(a.size),a] = 1
y_train = b

a = y_test.reshape(-1)
b = np.zeros((a.size, a.max()+1))
b[np.arange(a.size),a] = 1
y_test = b

# %%
from tensorflow.keras.layers import Dense, Lambda, Dot, Activation, Concatenate
from tensorflow.keras.layers import Layer

# special thanks to Philippe Rémy for the imlementation of the Dot-Product Attention in Keras framework
# https://github.com/philipperemy/keras-attention-mechanism/blob/master/attention/attention.py

class Attention(Layer):

    def __init__(self, units=128, **kwargs):
        self.units = units
        super().__init__(**kwargs)

    def __call__(self, inputs):

        hidden_states = inputs
        hidden_size = int(hidden_states.shape[2])

        score_first_part = Dense(hidden_size, use_bias=False, name='attention_score_vec')(hidden_states)

        h_t = Lambda(lambda x: x[:, -1, :], output_shape=(hidden_size,), name='last_hidden_state')(hidden_states)
        score = Dot(axes=[1, 2], name='attention_score')([h_t, score_first_part])
        attention_weights = Activation('softmax', name='attention_weight')(score)
        context_vector = Dot(axes=[1, 1], name='context_vector')([hidden_states, attention_weights])
        pre_activation = Concatenate(name='attention_output')([context_vector, h_t])
        attention_vector = Dense(self.units, use_bias=False, activation='tanh', name='attention_vector')(pre_activation)
        return attention_vector

    def get_config(self):
        return {'units': self.units}

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %% [markdown]
# ### LSTM FCN with OHLC (+ Volume)

# %%
from keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Flatten, BatchNormalization, Reshape
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import GlobalAveragePooling1D
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import LeakyReLU
from keras.layers.merge import concatenate
from keras.models import Model
from keras.optimizers import Adam

# %%
def FCN_head():
    input1 = Input(shape=(12, 5))
    
    
    fcn = Conv1D(8, 3)(input1)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.15)(fcn)
    
    fcn = Conv1D(12, 5)(fcn)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.15)(fcn)
    
    fcn = Conv1D(8, 4)(fcn)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.15)(fcn)
    
    fcn = GlobalAveragePooling1D()(fcn)
    fcn = Flatten()(fcn)
    
    return input1, fcn

def LSTM_head():
    input2 = Input(shape=(12, 5))
    #alstm = Reshape((60, 1))(input2)
    lstm = LSTM(units = 100, return_sequences=True)(input2)
    lstm = Dropout(0.25)(lstm)
    lstm = LSTM(units = 59)(lstm)
    lstm = Dropout(0.15)(lstm)
    lstm = Dense(units = 30)(lstm)
    return input2, lstm

# %%
input_1, fcn = FCN_head()
input_2, alstm = LSTM_head()

merge = concatenate([fcn, alstm])

dense1 = Dense(100)(merge)
activ = LeakyReLU(alpha=0.1)(dense1)
output = Dense(units = 5, activation='softmax')(activ)

model = Model(inputs=[input_1, input_2], outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 12, 5)]      0
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 10, 8)        128         input_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 10, 8)        0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 10, 8)        32          dropout_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 10, 8)        0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6, 12)        492         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 6, 12)        0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 6, 12)        48          dropout_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 6, 12)        0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 3, 8)         392         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 12, 5)]      0
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 3, 8)         0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 12, 100)      42400       input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, 8)         32          dropout_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 12, 100)      0           lstm_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 3, 8)         0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 59)           37760       dropout_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 8)            0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 59)           0           lstm_7[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 8)            0           global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 30)           1800        dropout_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 38)           0           flatten_3[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          3900        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 100)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            505         leaky_re_lu_14[0][0]
# ==================================================================================================
# Total params: 87,489
# Trainable params: 87,433
# Non-trainable params: 56
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file="./images/lstm_fcn.png", show_shapes=True)

# %%
opt = Adam(learning_rate=0.0005)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
checkpoint_filepath = './tmp/lstm_fcn_01'

model_checkpoint_callback = ModelCheckpoint(
    filepath = checkpoint_filepath,
    save_weights_only = True,
    monitor = 'val_accuracy',
    mode = 'max',
    save_best_only = True)


cutpoint = -int(len(X_train)*0.2)

r = model.fit([X_train[:cutpoint], X_train[:cutpoint]],
              y_train[:cutpoint],
              validation_data=([X_test[cutpoint:], X_test[cutpoint:]], y_test[cutpoint:]), 
              epochs = 40,
              batch_size = 50, 
              callbacks=[model_checkpoint_callback])

model.load_weights(checkpoint_filepath)
model.save('./models/lstm_fcn_01')
# Out:
# Epoch 1/40
# 494/494 [==============================] - 90s 142ms/step - loss: 1.3295 - accuracy: 0.4015 - val_loss: 1.1566 - val_accuracy: 0.4956
# Epoch 2/40
# 494/494 [==============================] - 67s 136ms/step - loss: 1.0498 - accuracy: 0.5266 - val_loss: 0.8612 - val_accuracy: 0.6583
# Epoch 3/40
# 494/494 [==============================] - 68s 138ms/step - loss: 0.8205 - accuracy: 0.6395 - val_loss: 0.6584 - val_accuracy: 0.7271
# Epoch 4/40
# 494/494 [==============================] - 68s 137ms/step - loss: 0.7107 - accuracy: 0.6892 - val_loss: 0.6235 - val_accuracy: 0.7303
# Epoch 5/40
# 494/494 [==============================] - 70s 141ms/step - loss: 0.6668 - accuracy: 0.7163 - val_loss: 0.6323 - val_accuracy: 0.7350
# Epoch 6/40
# 494/494 [==============================] - 69s 139ms/step - loss: 0.6311 - accuracy: 0.7297 - val_loss: 0.5906 - val_accuracy: 0.7714
# Epoch 7/40
# 494/494 [==============================] - 69s 139ms/step - loss: 0.5981 - accuracy: 0.7427 - val_loss: 0.5725 - val_accuracy: 0.7802
# Epoch 8/40
# 494/494 [==============================] - 70s 141ms/step - loss: 0.5830 - accuracy: 0.7488 - val_loss: 0.5616 - val_accuracy: 0.7880
# Epoch 9/40
# 494/494 [==============================] - 70s 142ms/step - loss: 0.5620 - accuracy: 0.7633 - val_loss: 0.5686 - val_accuracy: 0.7866
# Epoch 10/40
# 494/494 [==============================] - 66s 134ms/step - loss: 0.5556 - accuracy: 0.7675 - val_loss: 0.4976 - val_accuracy: 0.8015
# Epoch 11/40
# 494/494 [==============================] - 67s 137ms/step - loss: 0.5363 - accuracy: 0.7779 - val_loss: 0.5232 - val_accuracy: 0.8085
# Epoch 12/40
# 494/494 [==============================] - 72s 145ms/step - loss: 0.5389 - accuracy: 0.7755 - val_loss: 0.4957 - val_accuracy: 0.8047
# Epoch 13/40
# 494/494 [==============================] - 70s 143ms/step - loss: 0.5254 - accuracy: 0.7771 - val_loss: 0.4906 - val_accuracy: 0.8032
# Epoch 14/40
# 494/494 [==============================] - 79s 160ms/step - loss: 0.5092 - accuracy: 0.7840 - val_loss: 0.4812 - val_accuracy: 0.8085
# Epoch 15/40
# 494/494 [==============================] - 70s 142ms/step - loss: 0.5052 - accuracy: 0.7864 - val_loss: 0.4816 - val_accuracy: 0.8061
# Epoch 16/40
# 494/494 [==============================] - 69s 140ms/step - loss: 0.4961 - accuracy: 0.7894 - val_loss: 0.5303 - val_accuracy: 0.7924
# Epoch 17/40
# 494/494 [==============================] - 72s 145ms/step - loss: 0.5071 - accuracy: 0.7804 - val_loss: 0.5097 - val_accuracy: 0.7945
# Epoch 18/40
# 494/494 [==============================] - 72s 145ms/step - loss: 0.4874 - accuracy: 0.7941 - val_loss: 0.4700 - val_accuracy: 0.8198
# Epoch 19/40
# 494/494 [==============================] - 71s 145ms/step - loss: 0.4844 - accuracy: 0.7969 - val_loss: 0.4556 - val_accuracy: 0.8117
# Epoch 20/40
# 494/494 [==============================] - 72s 146ms/step - loss: 0.4893 - accuracy: 0.7943 - val_loss: 0.4749 - val_accuracy: 0.8128
# Epoch 21/40
# 494/494 [==============================] - 70s 142ms/step - loss: 0.4836 - accuracy: 0.7968 - val_loss: 0.4649 - val_accuracy: 0.8146
# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from tensorflow import keras

model = keras.models.load_model('./models/lstm_fcn_01')

y_pred_2 = model.predict([X_test, X_test])

print("Overall accuracy: ",
      accuracy_score(relabel_prediction(y_test.argmax(axis=1)), relabel_prediction(y_pred_2.argmax(axis=1))), "\n")

matrix = confusion_matrix(y_test.argmax(axis=1), y_pred_2.argmax(axis=1))

class_percentages = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
for idx, pct in enumerate(class_percentages.diagonal()):
    print(f"class {idx} accuracy:", "{:.4f} %".format(pct*100))

df_cm = pd.DataFrame(matrix, index = [str(i) for i in range(5)],
                  columns = [str(i) for i in range(5)])
plt.figure(figsize = (16,10))
sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
# Out:
# Overall accuracy:  0.8236151603498543
#
# class 0 accuracy: 75.7576 %
# class 1 accuracy: 81.8471 %
# class 2 accuracy: 84.8345 %
# class 3 accuracy: 80.4124 %
# class 4 accuracy: 84.0659 %
# <AxesSubplot:>

# %% [markdown]
# ### LSTM FCN with OHLC (+ Volume) + Trades

# %%
dl_train2 = train_df.copy()

trades_df = pd.read_csv("./aggregated_data/5s_trades_all.csv")
trades_df.drop(["Unnamed: 0"], axis=1, inplace=True)

dl_train2 = pd.merge(dl_train2, trades_df, on="timestamp")

dl_train2["sentiment"] = \
(dl_train2["sentiment_weighted_avg_price"]>=1).astype(int).replace(0, -1)

dl_train2["sentiment_weighted_avg_price"] = np.abs(dl_train2["sentiment_weighted_avg_price"])

def windowed_value(wind_13):
    first = wind_13[0][:-1]
    whole =  wind_13[1:,:-1]
    side_values = np.array([i[-1] for i in wind_13])[1:]
    regularized = (whole/first)-1
    return np.hstack((regularized, side_values.reshape(-1,1)))


params = np.array(dl_train2.drop(["score", "timestamp", "class", "percs"], axis=1).values)
all_arr = list()
for i in tqdm(range(13, len(params))):
    all_arr.append(windowed_value(params[i-13:i]))

x = np.array(all_arr)

_y = np.array(dl_train2[["class"]].values)

y = _y

x = x
y = y[13:]

print(np.shape(x))
print(np.shape(y))
# Out:
#   0%|          | 0/34620 [00:00<?, ?it/s]
# (34620, 12, 9)
# (34620, 1)

# %%
# random shuffle
import random
from sklearn.model_selection import train_test_split

random.seed(42)

concat = list(zip(x,y))
random.shuffle(concat)

x, y = zip(*concat)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 42)
X_train, X_test, y_train, y_test = np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

## one-hot encoding
a = y_train.reshape(-1)
b = np.zeros((a.size, a.max()+1))
b[np.arange(a.size),a] = 1
y_train = b

a = y_test.reshape(-1)
b = np.zeros((a.size, a.max()+1))
b[np.arange(a.size),a] = 1
y_test = b

# %% [markdown]
# ### Model

# %%
def FCN_head():
    input1 = Input(shape=(12, 9))
    
    fcn = Conv1D(16, 3)(input1)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.15)(fcn)
    
    fcn = Conv1D(40, 5)(fcn)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.15)(fcn)
    
    fcn = Conv1D(24, 4)(fcn)
    fcn = Dropout(0.1)(fcn)
    fcn = BatchNormalization()(fcn)
    fcn = LeakyReLU(0.05)(fcn)
    
    fcn = GlobalAveragePooling1D()(fcn)
    fcn = Flatten()(fcn)
    
    return input1, fcn

def LSTM_head():
    input2 = Input(shape=(12, 9))
    #alstm = Reshape((60, 1))(input2)
    lstm = LSTM(units = 120, return_sequences=True)(input2)
    lstm = Dropout(0.25)(lstm)
    lstm = LSTM(units = 70)(lstm)
    lstm = Dropout(0.15)(lstm)
    lstm = Dense(units = 40)(lstm)
    return input2, lstm

# %%
input_1, fcn = FCN_head()
input_2, alstm = LSTM_head()

merge = concatenate([fcn, alstm])

dense1 = Dense(120)(merge)
activ = LeakyReLU(alpha=0.1)(dense1)
output = Dense(units = 5, activation='softmax')(activ)

model = Model(inputs=[input_1, input_2], outputs=output)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 12, 9)]      0
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 10, 16)       448         input_15[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 10, 16)       0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 10, 16)       64          dropout_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 10, 16)       0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 6, 40)        3240        leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 6, 40)        0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 40)        160         dropout_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 6, 40)        0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 3, 24)        3864        leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 12, 9)]      0
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 3, 24)        0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, 12, 120)      62400       input_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 3, 24)        96          dropout_35[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 12, 120)      0           lstm_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 3, 24)        0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 70)           53480       dropout_36[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 24)           0           leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 70)           0           lstm_15[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 24)           0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 40)           2840        dropout_37[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64)           0           flatten_7[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 120)          7800        concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 120)          0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 5)            605         leaky_re_lu_30[0][0]
# ==================================================================================================
# Total params: 134,997
# Trainable params: 134,837
# Non-trainable params: 160
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file="./images/lstm_fcn_02.png", show_shapes=True)

# %%
opt = Adam(learning_rate=0.0005)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
checkpoint_filepath = './tmp/lstm_fcn_02'

model_checkpoint_callback = ModelCheckpoint(
    filepath = checkpoint_filepath,
    save_weights_only = True,
    monitor = 'val_accuracy',
    mode = 'max',
    save_best_only = True)


cutpoint = -int(len(X_train)*0.2)

r = model.fit([X_train[:cutpoint], X_train[:cutpoint]],
              y_train[:cutpoint],
              validation_data=([X_test[cutpoint:], X_test[cutpoint:]], y_test[cutpoint:]), 
              epochs = 40,
              batch_size = 50, 
              callbacks=[model_checkpoint_callback])

model.load_weights(checkpoint_filepath)
model.save('./models/lstm_fcn_02')
# Out:
# Epoch 1/40
# 499/499 [==============================] - 104s 167ms/step - loss: 1.4337 - accuracy: 0.3555 - val_loss: 1.3845 - val_accuracy: 0.3700
# Epoch 2/40
# 499/499 [==============================] - 82s 165ms/step - loss: 1.3741 - accuracy: 0.3763 - val_loss: 1.3566 - val_accuracy: 0.3836
# Epoch 3/40
# 499/499 [==============================] - 89s 179ms/step - loss: 1.3246 - accuracy: 0.3978 - val_loss: 1.0980 - val_accuracy: 0.4960
# Epoch 4/40
# 499/499 [==============================] - 85s 171ms/step - loss: 0.9999 - accuracy: 0.5479 - val_loss: 0.7521 - val_accuracy: 0.6762
# Epoch 5/40
# 499/499 [==============================] - 83s 166ms/step - loss: 0.7795 - accuracy: 0.6575 - val_loss: 0.6968 - val_accuracy: 0.7065
# Epoch 6/40
# 499/499 [==============================] - 85s 170ms/step - loss: 0.6863 - accuracy: 0.7045 - val_loss: 0.6717 - val_accuracy: 0.7088
# Epoch 7/40
# 499/499 [==============================] - 86s 172ms/step - loss: 0.4774 - accuracy: 0.8002 - val_loss: 0.4838 - val_accuracy: 0.8082
# Epoch 28/40
# 499/499 [==============================] - 87s 173ms/step - loss: 0.4856 - accuracy: 0.7922 - val_loss: 0.4713 - val_accuracy: 0.8016
# Epoch 29/40
# 499/499 [==============================] - 86s 172ms/step - loss: 0.4821 - accuracy: 0.7932 - val_loss: 0.4702 - val_accuracy: 0.8073
# Epoch 30/40
# 499/499 [==============================] - 87s 175ms/step - loss: 0.4843 - accuracy: 0.7954 - val_loss: 0.4812 - val_accuracy: 0.8013
# Epoch 31/40
# 499/499 [==============================] - 87s 174ms/step - loss: 0.4931 - accuracy: 0.7904 - val_loss: 0.4734 - val_accuracy: 0.8053
# Epoch 32/40
# 499/499 [==============================] - 88s 177ms/step - loss: 0.4800 - accuracy: 0.7989 - val_loss: 0.4772 - val_accuracy: 0.8016
# Epoch 33/40
# 499/499 [==============================] - 88s 176ms/step - loss: 0.4762 - accuracy: 0.8016 - val_loss: 0.4765 - val_accuracy: 0.8010
# Epoch 34/40
# 499/499 [==============================] - 88s 176ms/step - loss: 0.4676 - accuracy: 0.8045 - val_loss: 0.4701 - val_accuracy: 0.8085
# Epoch 35/40
# 499/499 [==============================] - 87s 175ms/step - loss: 0.4761 - accuracy: 0.8004 - val_loss: 0.4775 - val_accuracy: 0.8010
# Epoch 36/40
# 499/499 [==============================] - 81s 162ms/step - loss: 0.4731 - accuracy: 0.8051 - val_loss: 0.4979 - val_accuracy: 0.7972
# Epoch 37/40
# 499/499 [==============================] - 82s 165ms/step - loss: 0.4697 - accuracy: 0.8001 - val_loss: 0.4692 - val_accuracy: 0.8088
# Epoch 38/40
# 499/499 [==============================] - 83s 167ms/step - loss: 0.4628 - accuracy: 0.8051 - val_loss: 0.4845 - val_accuracy: 0.7972
# Epoch 39/40
# 499/499 [==============================] - 83s 166ms/step - loss: 0.4702 - accuracy: 0.8003 - val_loss: 0.4827 - val_accuracy: 0.7987
# Epoch 40/40
# 499/499 [==============================] - 82s 164ms/step - loss: 0.4753 - accuracy: 0.8006 - val_loss: 0.4961 - val_accuracy: 0.7958
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn, lstm_cell_17_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn, lstm_cell_16_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn, lstm_cell_17_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn, lstm_cell_16_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/lstm_fcn_02/assets
# INFO:tensorflow:Assets written to: ./models/lstm_fcn_02/assets

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from tensorflow import keras

model = keras.models.load_model('./models/lstm_fcn_02')

y_pred_2 = model.predict([X_test, X_test])

print("Overall accuracy: ",
      accuracy_score(relabel_prediction(y_test.argmax(axis=1)), relabel_prediction(y_pred_2.argmax(axis=1))), "\n")

matrix = confusion_matrix(y_test.argmax(axis=1), y_pred_2.argmax(axis=1))

class_percentages = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
for idx, pct in enumerate(class_percentages.diagonal()):
    print(f"class {idx} accuracy:", "{:.4f} %".format(pct*100))

df_cm = pd.DataFrame(matrix, index = [str(i) for i in range(5)],
                  columns = [str(i) for i in range(5)])
plt.figure(figsize = (16,10))
sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
# Out:
# Overall accuracy:  0.8087810514153668
#
# class 0 accuracy: 70.0855 %
# class 1 accuracy: 79.7086 %
# class 2 accuracy: 84.6755 %
# class 3 accuracy: 80.2730 %
# class 4 accuracy: 76.9231 %
# <AxesSubplot:>
